# %%
print("ok")
# Out:
# ok

# %% [markdown]
# mongodb+srv://Abdulla:@@Abdulla@@@cluster0.go4pcde.mongodb.net/?appName=Cluster0

# %% [markdown]
# mongodb+srv://Abdulla:@@Abdulla@@@cluster0.go4pcde.mongodb.net/?appName=Cluster0

# %% [markdown]
# mongodb+srv://Abdulla:%40%40Abdulla%40%40%40@cluster0.go4pcde.mongodb.net/?appName=Cluster0

# %% [markdown]
# mongodb+srv://Abdulla:<db_password>@cluster0.go4pcde.mongodb.net/?appName=Cluster0

# %% [markdown]
# mongodb+srv://Abdulla:Abdulla123@cluster0.go4pcde.mongodb.net/?retryWrites=true&w=majority

# %% [markdown]
# data link:https://www.kaggle.com/datasets/moro23/easyvisa-dataset
